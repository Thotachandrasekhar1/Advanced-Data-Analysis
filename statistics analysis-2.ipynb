# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Analysis 2

# %%
df=pd.read_csv(r"statistics Analysis-1")

# %%
df
# Out:
#         Unnamed: 0 dateCrawled  \
# 0                0  2016-03-24
# 1                2  2016-03-14
# 2                3  2016-03-17
# 3                4  2016-03-31
# 4                5  2016-04-04
# ...            ...         ...
# 340279      371521  2016-03-27
# 340280      371524  2016-03-05
# 340281      371525  2016-03-19
# 340282      371526  2016-03-20
# 340283      371527  2016-03-07
#
#                                                      name  seller offerType  \
# 0                                              Golf_3_1.6  privat   Angebot
# 1                          Jeep_Grand_Cherokee_"Overland"  privat   Angebot
# 2                                      GOLF_4_1_4__3TÜRER  privat   Angebot
# 3                          Skoda_Fabia_1.4_TDI_PD_Classic  privat   Angebot
# 4       BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat   Angebot
# ...                                                   ...     ...       ...
# ...

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df
# Out:
#        dateCrawled                                               name  seller  \
# 0       2016-03-24                                         Golf_3_1.6  privat
# 1       2016-03-14                     Jeep_Grand_Cherokee_"Overland"  privat
# 2       2016-03-17                                 GOLF_4_1_4__3TÜRER  privat
# 3       2016-03-31                     Skoda_Fabia_1.4_TDI_PD_Classic  privat
# 4       2016-04-04  BMW_316i___e36_Limousine___Bastlerfahrzeug__Ex...  privat
# ...            ...                                                ...     ...
# 340279  2016-03-27                 Opel_Zafira_1.6_Elegance_TÜV_12/16  privat
# 340280  2016-03-05              Smart_smart_leistungssteigerung_100ps  privat
# 340281  2016-03-19                 Volkswagen_Multivan_T4_TDI_7DC_UY2  privat
# 340282  2016-03-20                             VW_Golf_Kombi_1_9l_TDI  privat
# 340283  2016-03-07       BMW_M135i_vollausgestattet_NP_52.720____Euro  privat
#
# ...

# %% [markdown]
# ### Can you tell me No of Vehicles by Brand Available on ebay for sale with the help of visualization

# %%
df["brand"].value_counts().plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# These are the no.of vehicles by brand available on ebay for sale.

# %% [markdown]
# ### 2) What is the Average price for vehicles based on the type of vehicle as well as on the type of gearbox.Explain me with both numerical and visualization analysis

# %%
a=pd.crosstab(index =df['vehicleType'],columns =df["gearbox"], values = df['price'],aggfunc='mean' )

# %%
a
# Out:
# gearbox         automatik       manuell
# vehicleType
# andere        8535.707819   4040.197784
# bus          10926.346774   6047.074835
# cabrio       16058.176796   8804.126836
# coupe        16209.865955  10064.038935
# kleinwagen    4004.249388   2758.509936
# kombi         9075.676357   4856.891430
# limousine     9419.215696   4204.549341
# suv          17145.914836  10214.561145

# %%
a.plot(kind="bar")
# Out:
# <Axes: xlabel='vehicleType'>

# %% [markdown]
# ### What is the marginal probability of private seller

# %%
df["seller"].unique()
# Out:
# array(['privat', 'gewerblich'], dtype=object)

# %%
df["seller"].value_counts()/len(df)
# Out:
# privat        0.999991
# gewerblich    0.000009
# Name: seller, dtype: float64

# %% [markdown]
# This is the marginal probabaility of the private seller
